# %% [markdown]
# ## How to take notes
# Slipbox is an idea generator which should have code to work propely.
# Going to use notebooks to have support for code in the notes.
#
# For a note to have any value it should have a link to another note for it to exists. Indexing should be done from a writers perspective. It takes effort to come up with good indexes.
#
# Structure/limits are good for forcing work. Since the more restrictions you have the easier it is to come up with some actually work.

# %% [markdown]
# Rereading does nothing, change is important for teaching. The unexpected gives more than the expected.
# Its important to forget. Compression is forgetting.

# %% [markdown]
# ## Writing
# To lear Read wRite Reasoning (RRR) is one of the good ways to learn. All topics are equally intersting.
