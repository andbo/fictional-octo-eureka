# %% [markdown]
# # watchy software
#
# Install [platformio](https://platformio.org/) extension for vscode. allows for uploading and compiling of the watchy software.
#
# Try out one of the faces: https://watchy.sqfmi.com/watchfaces
