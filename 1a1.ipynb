# %% [markdown]
# # Bicep
#
# MS developed tool. Language that generates ARM templates.
#
# Develop the same platforms in parallel.
# Get vscode in the browser so its can be coded
#
# Deployment of bicep is not clear yet for me.
#
#
# [Example of a dataplatform in bicep](https://www.thedataswamp.com/blog/deploy-your-own-bicep-azure-data-platfrom)
# [Source code of the example](https://github.com/thelonemoody/Bicep-Data-Platform)

# %% [markdown]
# The [uniquestring](https://docs.microsoft.com/en-us/azure/azure-resource-manager/templates/template-functions-string#uniquestring) function returns a 13 char long string it is not globally unique but very likely to be it if you add another string to it
