# %% [markdown]
# # NREL Fast
#
# Intro guide for how to get FAST up and running in Azure.
# FAST farm setup for Azure including infrastruktur.
#
# [OpenFAST](https://github.com/OpenFAST) is the org in github with the new fast code.
# Construct a simple guide that uses the [SourceCode for Fast](https://github.com/OpenFAST/openfast) and get it running.
